# %%
import os
import re
import inspect

# %% [markdown]
# # Defining functions to parse .ipf files
#
# - `get_function_in_file` Example return {'scans.ipf':['scanfastdac', 'scanfastdac2d', ...]}
# - `function_in_list` Example return ['scanfastdac', 'initscancontroller', ...]
# - `get_file_names` Example return ['scans.ipf', 'scancontroller.ipf', ...]
# - `function_in_functions` Example return {'scanfastdac':['sc_openinstrconnections', 'initScanVarsFD', ...]}

# %%
def get_function_in_file(folder_path):
    """
    Retrieves the functions defined in each file within the specified folder path.

    Args:
        folder_path (str): The path to the folder containing the files.

    Returns:
        dict: A dictionary mapping file names to the list of functions defined in each file.
    """
    dependencies = {}

    # Iterate over each file in the folder
    for filename in os.listdir(folder_path):
        functions = []
        if filename.endswith(".ipf"):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r') as file:
                function_name = ''
                for line in file:
                    line = line.strip()
                    # if line.startswith("function"):
                    if re.search(r'^(?:threadsafe\s*)?function.*', line):
                        function_name = line.split('function')[1].split('(')[0].split(' ')[-1]
                        if function_name != "":
                            functions.append(function_name.lower())

        dependencies[filename] = functions

    return dependencies


def function_in_list(function_in_file):
    """
    Returns a list of functions from a dictionary of functions in files.

    Args:
        function_in_file (dict): A dictionary mapping file names to the list of functions defined in each file.

    Returns:
        function_list: A list of functions extracted from the input dictionary.
    """
    function_list = []
    for file, functions in function_in_file.items():
        function_list += functions

    return function_list



def get_file_names(folder_path):
    """
    Retrieves the names of files with the ".ipf" extension within the specified folder.

    Args:
        folder_path (str): The path to the folder containing the files.

    Returns:
        files: A list of file names with the ".ipf" extension.

    """
    files = []

    for filename in os.listdir(folder_path):
        functions = []
        if filename.endswith(".ipf"):
            files.append(filename)

    return files



def function_in_functions(folder_path, function_name='scanfastdac'):
    """
    Retrieves the dependencies of a specific function within a folder of files.

    Args:
        folder_path (str): The path to the folder containing the files.
        function_name (str, optional): The name of the function to find dependencies for. Defaults to 'scanfastdac'.

    Returns:
        dependencies: A dictionary mapping the specified function to a list of its dependencies.

    """

    function_in_file = get_function_in_file(folder_path)
    function_list = function_in_list(function_in_file)

    dependencies = {}

    for file, functions in function_in_file.items():
        file_path = os.path.join(folder_path, file)
        for function in functions:
            if function == function_name:
                do_print = True
            else:
                do_print = False

            called_functions = []
            with open(file_path, 'r') as file:
                function_reached = False
                for line in file:
                    line = line.strip()
                    line = line.lower()
                    if re.search(r'^(?:threadsafe\s*)?function.*', line) and line.split('function')[1].split('(')[0].split(' ')[-1].lower() == function:
                        function_reached = True
                    if re.match(r'^\s*end\b *', line)  and function_reached == True:
                        function_reached = False
                    if function_reached == True:
                        # if do_print: # print every line in the function 
                        #     print(line)
                        for loop_function in function_list:
                            if loop_function in line and loop_function != function and loop_function not in called_functions and f'[{loop_function}]' not in line and not re.search(f"\/\/.*{loop_function}", line) and not re.search(f".*s.{loop_function}", line):
                                # if do_print: # print functions called within function
                                #     print(function, loop_function)
                                called_functions.append(loop_function)
            dependencies[function] = called_functions

    return dependencies

# %% [markdown]
# # Defining functions to create mermaid graph and save as .html
# - `generate_connections` Returns list of connections between given function and all functions that are recursovely called.
# - `generate_mermaid_graph` Returns a mermaid graph as a string.
# - `generate_html_with_mermaid` Create .html with mermaid graph.

# %%
def generate_connections(dependencies, function_name, visited_connection=None, visited_function=None):
    """
    Recursively generates the connections between given function and and all other functions that are called.

    Args:
        dependencies (dict): A dictionary mapping functions to their dependencies.
        function_name (str): The name of the function to generate connections for.
        visited_connection (list, optional): A list of visited connections to avoid duplicates. Defaults to None.
        visited_function (list, optional): A list of visited functions to avoid infinite recursion. Defaults to None.

    Returns:
        connections: A list containing a list of connections.
        dummy_functions: A list of visited functions.

    """
    if visited_connection is None:
        visited_connection = []

    if visited_function is None:
        visited_function = []
        
    dummy_functions = visited_function
    
    connections = []
    if function_name in dependencies and function_name not in visited_function:
        visited_function.append(function_name)
        called_functions = dependencies[function_name]
        for called_function in called_functions:
            connection = f"{function_name} --> {called_function};"
            if connection not in visited_connection:
                visited_connection.append(connection)
                connections.append(connection)
                generated_connections, dummy_functions = generate_connections(dependencies, called_function, visited_connection=visited_connection, visited_function=visited_function)
                connections.extend(generated_connections)
    return connections, dummy_functions



def generate_mermaid_graph(connections, visited_functions, function_in_file):
    """
    Generates a mermaid graph based on the connections between functions.

    Args:
        connections (list): A list of connections between functions.
        visited_functions (list): A list of visited functions.
        function_in_file (dict): A dictionary mapping files to their respective functions.

    Returns:
        str: The generated mermaid graph as a string.

    """
    m_graph = ['graph TB;']
    m_graph += connections
    for file, functions in function_in_file.items():
        visited = False
        m_graph.append(f'subgraph {file}')
        for function in functions:
            if function in visited_functions:
                m_graph.append(f'{function}')
                visited = True
        if visited:
            m_graph.append(f'end')
        else:
            m_graph = m_graph[:-1]
    return '\n'.join(m_graph)



def generate_html_with_mermaid(mermaid_graph, file_path=None):
    """
    Generates an HTML file with a mermaid diagram in the given file_path.

    Args:
        mermaid_graph (str): The mermaid graph as a string.
        file_path (str, optional): The file path to save the HTML file. If not provided, 'output.html' will be used.

    Returns:
        None

    """
    html_content = inspect.cleandoc(f"""
    <html>
    <body>
    <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/3.6.0/jquery.min.js"></script>
    <script src="https://cdnjs.cloudflare.com/ajax/libs/zoomooz/1.4.1/zoomooz.min.js"></script>
    <style>
        .mermaid {{
            height: 600px; /* Adjust the height as needed */
            margin-bottom: 20px; /* Adjust the bottom margin as needed */
        }}
    </style>
    <pre class="mermaid">
    {mermaid_graph}
    </pre>
    <script type="module">
    import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.1/dist/mermaid.esm.min.mjs';
    mermaid.initialize({{
        startOnLoad: true,
        flowchart: {{
                useMaxWidth: false, // Disable maximum width for better zooming
                htmlLabels: true, // Enable HTML-based labels for better styling
                defaultRenderer: "elk", // Makes connections linear, ugly but good for large graphs
            }},
        }});
    $(document).ready(function() {{
            // Apply Zoomooz to the Mermaid diagram container
            $('.mermaid').zoomTarget();
        }});
    </script>
    </body>
    </html>
    """)


    if file_path is None:
        file_path = 'output.html'
    with open(file_path, 'w') as file:
        file.write(html_content)

# %% [markdown]
# # Parsing .ipf to get functions in each .ipf file

# %%
# Example usage
folder_path = '../Required'  # Replace with the actual folder path
function_in_file = get_function_in_file(folder_path)

# %% [markdown]
# # Example creating .html for one function

# %%
##### Example running for one function #####
function_to_view = 'setls625fieldwait'
function_functions = function_in_functions(folder_path, function_name=function_to_view)
single_function_web, visited_functions = generate_connections(function_functions, function_name=function_to_view)
mermaid_graph = generate_mermaid_graph(single_function_web, visited_functions, function_in_file)
generate_html_with_mermaid(mermaid_graph, file_path=f'{function_to_view}.html')

# %% [markdown]
# # Example creating .html for EVERY FUNCTION in Repo...

# %%
def create_master_web(folder_path, function_in_file, ipf_path):
    if not os.path.exists(folder_path):
            os.makedirs(folder_path)

    function_functions = function_in_functions(ipf_path)

    for file, functions_to_view in function_in_file.items():
        print(f'Starting {file}')
        full_path = f'{folder_path}/{file.split(".ipf")[0]}'
        if not os.path.exists(full_path):
            os.makedirs(full_path)            
            
        for function_to_view in functions_to_view:
            single_function_web, visited_functions = generate_connections(function_functions, function_name=function_to_view)
            mermaid_graph = generate_mermaid_graph(single_function_web, visited_functions, function_in_file)
            generate_html_with_mermaid(mermaid_graph, file_path=f'{full_path}/{function_to_view}.html')


create_master_web('html_function_webs', function_in_file, '../Required')
# Out:
# Starting babydac.ipf
# Starting fastdac.ipf
# Starting hp34401A.ipf
# Starting ips120_single_supply.ipf
# Starting keithley2400.ipf
# Starting ls370_resistancebridge.ipf
# Starting ls625_single_supply.ipf
# Starting ScanController.ipf
# Starting ScanController_INSTR.ipf
# Starting ScanController_IO.ipf
# Starting ScanController_SQL.ipf
# Starting Scans.ipf
# Starting srs830.ipf

# %% [markdown]
# # Printing all the functions that call function x

# %%
function_functions = function_in_functions(folder_path)

# %%
function_functions
# Out:
# {'openbabydacconnection': ['visaerrormsg', 'openvisainstr'],
#  'initbabydacs': ['getresourceaddress',
#   'bd_setboardnumbers',
#   'bd_setchannelrange',
#   'bd_checkforoldinit'],
#  'bd_setboardnumbers': [],
#  'bd_setchannelrange': [],
#  'bd_checkforoldinit': ['bd_initaskuser',
#   'bd_createcustomwaves',
#   'bd_calccustomvalues',
#   'bd_initzeros'],
#  'bd_createcustomwaves': ['bd_createvectors'],
#  'bd_calccustomvalues': [],
#  'bd_createvectors': [],
#  'bd_initzeros': [],
#  'bd_initaskuser': [],
#  'bd_getboard': [],
#  'bd_getboardchannel': ['bd_getboard'],
#  'bd_writebytesbd': ['visaerrormsg'],
#  'bd_readsinglebytebd': ['visaerrormsg'],
#  'bd_readbytesbd': ['bd_readsinglebytebd'],
#  'clearbufferbd': [],
#  'resetstartupvoltagebd': ['clearbufferbd',
#   'bd_writebytesbd',
#   'bd_readbytesbd',
#   'sc_sleep'],
#  'bd_getsetpointbd': [],
#  'bd_setoutputbd': ['bd_getboard',
#   'bd_getboardchannel',
#   'bd_getsetpointbd',
#   'bd_writebytesbd',
#   'bd_readbytesbd'],
#  'bd_rampoutputbd': ['bd_setoutputbd', 'sc_sleep'],
#  'bd_updatemultiplebd': ['bd_setoutputbd', 'bd_rampoutputbd'],
#  'rampmultiplebd': ['scu_getchannelnumbers',
#   'bd_channellookup',
#   'bd_updatecustom',
#   'bd_updatemultiplebd',
#   'bd_calccustomvalues'],
#  'bd_channellookup': [],
#  'bd_updatecustom': [],
#  'bd_setallzerobd': ['bd_rampoutputbd', 'sc_sleep'],
#  'bdloadfromhdf': ['bd_get_babydacs_from_hdf',
#   'bd_loadaskuser',
#   'openbabydacconnection',
#   'bd_updatemultiplebd'],
#  'bd_get_babydacs_from_hdf': ['get_sweeplogs', 'getjsonxid'],
#  'bd_loadaskuser': [],
#  'bd_loadaskuserbutton': ['bd_loadaskuser'],
#  'bd_reading2voltage': [],
#  'bd_readbdadc': ['bd_writebytesbd',
#   'bd_readsinglebytebd',
#   'bd_readbytesbd',
#   'bd_reading2voltage'],
#  'bd_askuserupdate': [],
#  'bd_update_babydac': ['openbabydacconnection',
#   'bd_updatemultiplebd',
#   'bd_rampoutputbd',
#   'bd_calccustomvalues'],
#  'bd_update_babydac_custom': ['bd_update_babydac',
#   'openbabydacconnection',
#   'rampmultiplebd'],
#  'bd_calcvectors': ['bd_createvectors', 'bd_calccustomvalues'],
#  'getbdstatus': ['addjsonkeyval'],
#  'getbddacvalue': ['scu_getchannelnumbers'],
#  'openfastdacconnection': ['visaerrormsg', 'openvisainstr', 'scf_addfdinfos'],
#  'openmultiplefdacs': ['removewhitespace', 'openfastdacconnection'],
#  'set_master_slave': ['queryinstr'],
#  'set_indep': ['clearfdacbuffer', 'queryinstr'],
#  'getfadcmeasurefreq': ['scf_getnumrecordedadcs', 'getfadcspeed'],
#  'getfadcspeed': ['queryinstr',
#   'sc_striptermination',
#   'scf_checkfdresponse',
#   'scf_getfdnumber',
#   'scf_getfdinfofromid'],
#  'getfadcchannel': ['scc_getdeviceids', 'getfadcspeed', 'fd_readchunk'],
#  'getfadcvalue': ['getfadcchannel'],
#  'getfadcchannelsingle': ['getfadcchannel',
#   'scf_getchannelnumsonfd',
#   'scf_checkinstridmatchesdevice',
#   'queryinstr',
#   'sc_striptermination',
#   'scf_checkfdresponse'],
#  'getfdacoutput': ['scf_getchannelstartnum',
#   'queryinstr',
#   'sc_striptermination',
#   'scf_checkfdresponse'],
#  'getmultiplefdstatus': ['removewhitespace', 'getfdstatus'],
#  'getfdstatus': ['getresourceaddress',
#   'addjsonkeyval',
#   'getfadcspeed',
#   'getfadcmeasurefreq',
#   'scf_getfdnumber',
#   'scf_getchannelstartnum',
#   'scf_getfdinfofromid',
#   'num2numstr',
#   'getfadcchannel'],
#  'getfdawgstatus': ['fd_getglobalawg', 'addjsonkeyval'],
#  'setfadcspeed': ['scf_getnumfds',
#   'getresourceaddress',
#   'scf_getfdvisaaddress',
#   'scf_getfdinfofromdevicenum',
#   'queryinstr',
#   'sc_striptermination',
#   'scf_checkfdresponse',
#   'roundnum',
#   'fd_loadfadccalibration',
#   'calibratefadc',
#   'fd_setawguninitialized',
#   'setawg'],
#  'rampmultiplechannels': ['scu_getchannelnumbers',
#   'scc_getdeviceids',
#   'rampmultiplefdac'],
#  'rampmultiplefdac': ['scu_assertseparatortype',
#   'scu_getchannelnumbers',
#   'scf_getdacinfo',
#   'fd_rampoutputfdac'],
#  'fd_rampoutputfdac': ['getresourceaddress',
#   'scfw_resetfdacwindow',
#   'getfdacoutput',
#   'queryinstr',
#   'queryinstrprogress',
#   'sc_striptermination',
#   'scf_checkfdresponse',
#   'scfw_updatefdacvalstr'],
#  'startpid': ['writeinstr'],
#  'stoppid': ['writeinstr'],
#  'setpidtune': ['writeinstr'],
#  'setpidsetp': ['writeinstr'],
#  'setpidlims': ['writeinstr'],
#  'setpiddir': ['writeinstr'],
#  'setpidslew': ['writeinstr'],
#  'fd_loadfadccalibration': ['getresourceaddress',
#   'readtxtfile',
#   'getjsonvalue',
#   'fd_updatefadccalibration'],
#  'calibratefdac': ['sc_openinstrconnections',
#   'initfastdac',
#   'ask_user',
#   'getresourceaddress',
#   'fd_resetfdaccalibration',
#   'fd_rampoutputfdac',
#   'scf_getchannelstartnum',
#   'prompt_user',
#   'fd_setfdaccalibrationoffset',
#   'fd_setfdaccalibrationgain',
#   'fd_savefdaccalibration'],
#  'calibratefadc': ['initfastdac',
#   'getresourceaddress',
#   'getfadcspeed',
#   'roundnum',
#   'ask_user',
#   'queryinstr',
#   'sc_striptermination',
#   'readinstr',
#   'scf_checkfdresponse',
#   'fd_rampoutputfdac',
#   'scf_getchannelstartnum',
#   'fd_savefadccalibration'],
#  'fd_savefadccalibration': ['addjsonkeyval', 'writetofile', 'prettyjsonfmt'],
#  'fd_savefdaccalibration': ['addjsonkeyval',
#   'scu_unixtime',
#   'writetofile',
#   'prettyjsonfmt'],
#  'fd_resetfdaccalibration': ['queryinstr',
#   'sc_striptermination',
#   'scf_checkfdresponse'],
#  'fd_setfdaccalibrationoffset': ['queryinstr',
#   'sc_striptermination',
#   'readinstr',
#   'scf_checkfdresponse'],
#  'fd_setfdaccalibrationgain': ['queryinstr',
#   'sc_striptermination',
#   'readinstr',
#   'scf_checkfdresponse'],
#  'fd_updatefadccalibration': ['queryinstr',
#   'sc_striptermination',
#   'scf_checkfdresponse'],
#  'fd_get_numpts_from_sweeprate': [],
#  'fd_get_sweeprate_from_numpts': [],
#  'clearfdacbuffer': ['writeinstr'],
#  'fd_stopfdacsweep': ['clearfdacbuffer'],
#  'fd_char2num': [],
#  'fdspectrumanalyzer': ['initscanvars',
#   'initscanvarsfd',
#   'initscanvarsfd2',
#   'scc_checklimsfd',
#   'rampstartfd',
#   'sc_sleep',
#   'initializescan',
#   'scf_getnumrecordedadcs',
#   'scf_getrecordedfadcinfo',
#   'scg_initializegraphs',
#   'scg_initializegraphsforwavenames',
#   'scg_arrangewindows',
#   'recordvalues',
#   'scfd_recordvalues',
#   'fd_calculate_spectrum',
#   'endscan'],
#  'fd_calculate_spectrum': [],
#  'plotpowerspectrum': ['fd_calculate_spectrum',
#   'scg_initializegraphs',
#   'scg_initializegraphsforwavenames'],
#  'fdloadfromhdf': ['fd_get_fastdacs_from_hdf',
#   'fd_loadaskuser',
#   'scfw_update_all_fdac'],
#  'fd_get_fastdacs_from_hdf': ['get_sweeplogs', 'getjsonxid'],
#  'fd_loadaskuser': [],
#  'fd_loadaskuserbutton': ['fd_loadaskuser'],
#  'setfdacawgsquarewave': ['fd_getglobalawg',
#   'scf_getnumrecordedadcs',
#   'scf_getmaxrecordedadcs',
#   'fd_setglobalawg',
#   'getfadcspeed',
#   'fd_clearawgwave',
#   'fd_addawgwave'],
#  'setupawg': ['fd_getglobalawg',
#   'scu_getchannelnumbers',
#   'scf_getmaxrecordedadcs',
#   'scf_getnumrecordedadcs',
#   'scc_getdeviceids',
#   'textwavetolist',
#   'scv_setfreq',
#   'scv_setfreq2',
#   'fd_getawgwave',
#   'fd_checkaw',
#   'fd_setglobalawg'],
#  'fd_setawguninitialized': ['setawg', 'fd_getglobalawg', 'fd_setglobalawg'],
#  'fd_checkaw': [],
#  'fd_addawgwave': ['queryinstr',
#   'sc_striptermination',
#   'fd_getawgwave',
#   'scf_checkfdresponse'],
#  'fd_getawgwave': [],
#  'fd_clearawgwave': ['queryinstr',
#   'sc_striptermination',
#   'scf_checkfdresponse',
#   'fd_getawgwave'],
#  'fd_start_sweep': ['scu_assertseparatortype',
#   'queryinstr',
#   'scu_getdevicechannels',
#   'removeseperator',
#   'getfdacoutput',
#   'setupfakesquarewave',
#   'setupawg',
#   'scw_setupawg',
#   'writeinstr'],
#  'fd_readchunk': ['getfadcspeed', 'recordvalues', 'scfd_recordvalues'],
#  'fd_initglobalawg': ['fd_setglobalawg'],
#  'fd_setglobalawg': [],
#  'setawg': ['fd_getglobalawg', 'fd_setglobalawg'],
#  'fd_getglobalawg': ['fd_initglobalawg'],
#  'openhp34401aconnection': ['visaerrormsg', 'openvisainstr'],
#  'setup34401adcvolts': ['writeinstr', 'sc_sleep'],
#  'setup34401aacvolts': ['writeinstr', 'sc_sleep'],
#  'get34401aidn': ['queryinstr'],
#  'get34401ajunk': [],
#  'geterrors34401a': ['queryinstr'],
#  'setspeed34401a': ['writeinstr'],
#  'check34401aconfig': ['queryinstr'],
#  'settext34401a': ['writeinstr'],
#  'read34401a': ['queryinstr'],
#  'get34401astatus': ['getaddressgpib', 'addjsonkeyval', 'check34401aconfig'],
#  'openips120connection': ['visaerrormsg',
#   'openvisainstr',
#   'writeipscheck',
#   'sc_sleep',
#   'writeinstr'],
#  'ips120_lookupvarname': [],
#  'writeipscheck': ['queryinstr'],
#  'getips120volts': ['queryinstr'],
#  'getips120current': ['queryinstr'],
#  'getips120field': ['ips120_lookupvarname', 'queryinstr', 'roundnum'],
#  'getips120rate': ['ips120_lookupvarname', 'queryinstr', 'roundnum'],
#  'getips120rate_current': ['getips120rate',
#   'ips120_lookupvarname',
#   'queryinstr',
#   'roundnum'],
#  'getips120status': ['writeinstr', 'readinstr'],
#  'getips120heaterstatus': ['getips120status'],
#  'setips120current': ['ips120_lookupvarname', 'writeipscheck', 'writeinstr'],
#  'setips120field': ['ips120_lookupvarname',
#   'roundnum',
#   'writeipscheck',
#   'writeinstr'],
#  'setips120rate': ['ips120_lookupvarname', 'roundnum', 'writeipscheck'],
#  'setips120switchheater': ['getips120heaterstatus', 'writeipscheck'],
#  'setips120fieldwait': ['setips120field', 'asleep', 'queryinstr'],
#  'getipsstatus': ['getips120field',
#   'addjsonkeyval',
#   'getips120rate',
#   'getresourceaddress'],
#  'openk2400connection': ['visaerrormsg', 'openvisainstr'],
#  'setk2400current': ['writeinstr'],
#  'setk2400voltage': ['writeinstr'],
#  'getk2400current': ['writeinstr', 'queryinstr'],
#  'getk2400voltage': ['writeinstr', 'queryinstr'],
#  'rampmultiplek2400s': ['checkstartsfinschannels', 'rampk2400voltage'],
#  'rampk2400voltage': ['getk2400voltage', 'setk2400voltage', 'sc_sleep'],
#  'rampk2400current': ['getk2400current', 'setk2400current', 'sc_sleep'],
#  'setk2400compl': ['writeinstr'],
#  'setk2400range': ['writeinstr'],
#  'setk2400output': ['writeinstr'],
#  'setk2400autorange': ['writeinstr'],
#  'getk2400status': [],
#  'openls370connection': ['openhttpinstr',
#   'setls370system',
#   'ls370creategobals'],
#  'setls370system': ['bd_channellookup'],
#  'getls370channellabel': ['bd_channellookup'],
#  'getls370analogdata': ['sendls370'],
#  'getls370analogparameters': ['sendls370'],
#  'getls370temp': ['bd_channellookup', 'getls370channellabel', 'sendls370'],
#  'getls370controllerinfo': ['sendls370'],
#  'getls370loggersschedule': ['sendls370'],
#  'getls370heaterpower': ['getls370analogdata', 'sendls370'],
#  'getls370heaterrange': ['sendls370'],
#  'getls370controlmode': ['sendls370', 'ls370_mode_str_to_mode'],
#  'getls370controlparameters': ['sendls370'],
#  'getls370pidtemp': ['sendls370'],
#  'getls370pidparameters': ['sendls370', 'getjsonvalue'],
#  'setls370analogoutputparameters': ['sendls370'],
#  'setls370loggersschedule': ['ls370getloggingschedulefromconfig', 'sendls370'],
#  'setls370heaterpower': ['sendls370'],
#  'setls370heaterrange': ['sendls370'],
#  'setls370controlmode': ['ls370_mode_to_str', 'sendls370'],
#  'setls370controlparameters': ['bd_channellookup', 'sendls370'],
#  'setls370tempsetpoint': ['setls370temp', 'sendls370'],
#  'setls370pidparameters': ['sendls370'],
#  'setls370heateroff': ['sendls370'],
#  'setls370temp': ['ls370_estimateheaterrange',
#   'setls370controlmode',
#   'setls370heaterrange',
#   'setls370tempsetpoint'],
#  'setls370exclusivereader': ['setls370loggersschedule'],
#  'resetls370exclusivereader': ['setls370exclusivereader',
#   'setls370loggersschedule'],
#  'waittilltempstable': ['asleep', 'getls370temp'],
#  'ls370getloggingschedulefromconfig': ['readtxtfile', 'getjsonxid'],
#  'ls370_mode_to_str': [],
#  'ls370_mode_str_to_mode': [],
#  'ls370_estimateheaterrange': [],
#  'ls370creategobals': [],
#  'sendls370': ['gethttp', 'posthttp', 'puthttp', 'getjsonvalue'],
#  'getls370status': ['readtxtfile',
#   'getjsonvalue',
#   'sc_sqltimestamp',
#   'requestsqlvalue',
#   'getls370temp',
#   'addjsonkeyval'],
#  'getls370status_nosql': ['getls370temp', 'addjsonkeyval'],
#  'getbfstatus': ['readtxtfile',
#   'getjsonvalue',
#   'sc_sqltimestamp',
#   'requestsqlvalue',
#   'addjsonkeyval'],
#  'getls370heaterstatus': ['getls370heaterpower',
#   'getls370heaterrange',
#   'getls370pidtemp',
#   'sendls370',
#   'getls370controlparameters',
#   'getls370controllerinfo',
#   'getls370analogparameters'],
#  'test_lakeshore': ['setls370controlparameters',
#   'test_lakeshore_ask_continue',
#   'getls370controlparameters',
#   'getls370heaterpower',
#   'setls370heaterpower',
#   'setls370heateroff',
#   'getls370pidparameters',
#   'setls370pidparameters',
#   'getls370controlmode',
#   'setls370controlmode',
#   'getls370pidtemp',
#   'setls370tempsetpoint',
#   'setls370temp',
#   'getls370heaterrange',
#   'setls370heaterrange',
#   'getls370loggersschedule',
#   'setls370loggersschedule'],
#  'test_lakeshore_ask_continue': ['test_lakeshore', 'ask_user'],
#  'openls625connection': ['visaerrormsg', 'openvisainstr'],
#  'ls625_lookupvarname': [],
#  'getls625current': ['queryinstr'],
#  'getls625field': ['ls625_lookupvarname', 'getls625current', 'roundnum'],
#  'getls625rate': ['ls625_lookupvarname', 'queryinstr', 'roundnum'],
#  'getls625rampstatus': ['queryinstr'],
#  'setls625current': ['ls625_lookupvarname', 'writeinstr'],
#  'setls625field': ['ls625_lookupvarname', 'roundnum', 'setls625current'],
#  'setls625fieldwait': ['setls625field', 'asleep', 'getls625rampstatus'],
#  'setls625rate': ['ls625_lookupvarname', 'roundnum', 'writeinstr'],
#  'getls625status': ['ls625_lookupvarname',
#   'addjsonkeyval',
#   'getls625field',
#   'getls625rate'],
#  'scu_assertseparatortype': [],
#  'scu_unixtime': [],
#  'roundnum': [],
#  'appendvalue': [],
#  'appendstring': [],
#  'prompt_user': [],
#  'ask_user': [],
#  'scu_getdaclabel': ['scu_assertseparatortype'],
#  'scu_getchannelnumbers': ['scu_assertseparatortype',
#   'removetrailingwhitespace'],
#  'scu_getdevicechannels': ['scf_getfdinfofromid', 'scf_getchannelstartnum'],
#  'sc_sleep': ['scs_checksweepstate'],
#  'asleep': ['sc_sleep'],
#  'sc_sleep_noupdate': ['sc_sleep'],
#  'scv_setlastscanvars': [],
#  'scv_getlastscanvars': [],
#  'initscanvars': [],
#  'initscanvarsfd': ['initscanvars',
#   'scf_getrecordedfadcinfo',
#   'scu_getdaclabel',
#   'scv_setsetpoints',
#   'scv_setfreq',
#   'scv_setnumptssweeprateduration'],
#  'initscanvarsfd2': ['initscanvars',
#   'initscanvarsfd',
#   'scf_getrecordedfadcinfo',
#   'scu_getdaclabel',
#   'scc_getdeviceids',
#   'fd_getglobalawg',
#   'textwavetolist',
#   'get_values',
#   'scf_getmaxrecordedadcs',
#   'scv_setsetpoints',
#   'scv_setfreq',
#   'scv_setfreq2',
#   'scv_setnumptssweeprateduration',
#   'scu_getchannelnumbers'],
#  'initscanvarsbd': ['initscanvars', 'scv_setsetpoints', 'scu_getdaclabel'],
#  'scv_setnumptssweeprateduration': ['fd_get_sweeprate_from_numpts',
#   'fd_get_numpts_from_sweeprate'],
#  'scv_setfreq': ['getfadcspeed', 'scf_getnumrecordedadcs'],
#  'scv_setfreq2': ['scv_setfreq', 'getfadcspeed'],
#  'scv_setsetpoints': ['scv_formatsetpoints', 'scv_sanitizesetpoints'],
#  'scv_sanitizesetpoints': ['scu_assertseparatortype'],
#  'scv_formatsetpoints': [],
#  'initializescan': ['sci_initializewaves',
#   'scg_initializegraphs',
#   'scg_arrangewindows',
#   'scg_openabortwindow',
#   'scv_setlastscanvars'],
#  'sci_initializewaves': ['fd_getglobalawg',
#   'sci_get1dwavenames',
#   'sci_sanitycheckwavenames',
#   'scfd_postfilternumpts',
#   'sci_init1dwave',
#   'sci_init2dwave',
#   'sc_findasyncmeasurements'],
#  'sci_init1dwave': [],
#  'sci_init2dwave': [],
#  'sci_get1dwavenames': ['scf_getrecordedfadcinfo'],
#  'sci_get2dwavenames': ['sci_get1dwavenames'],
#  'sci_sanitycheckwavenames': [],
#  'scg_initializegraphs': ['sci_get1dwavenames',
#   'scg_initializegraphsforwavenames'],
#  'scg_initializegraphsforwavenames': ['scg_graphexistsforwavename',
#   'scg_setupgraph1d',
#   'scg_open1dgraph',
#   'scfd_spectrum_analyzer',
#   'scg_twosubplot',
#   'scg_setupgraph2d',
#   'scg_open2dgraph'],
#  'scg_arrangewindows': [],
#  'scg_twosubplot': [],
#  'scg_graphexistsforwavename': ['scg_getopengraphtitles',
#   'scg_getopengraphids'],
#  'scg_open1dgraph': ['scg_setupgraph1d'],
#  'scg_open2dgraph': ['scg_setupgraph2d'],
#  'scg_setupgraph1d': [],
#  'scg_setupgraph2d': [],
#  'scg_getopengraphtitles': [],
#  'scg_getopengraphids': [],
#  'scg_openabortwindow': [],
#  'scg_updatefrequentgraphs': [],
#  'sc_openinstrconnections': [],
#  'sc_openinstrguis': [],
#  'sc_checkbackup': ['getexppath'],
#  'scs_stopsweep': [],
#  'scs_pausesweep': ['scs_resumesweep'],
#  'scs_resumesweep': ['scs_pausesweep'],
#  'scs_checksweepstate': ['endscan'],
#  'sc_managethreads': ['readvstime', 'sc_worker'],
#  'sc_worker': ['sc_funcasync'],
#  'sc_funcasync': [],
#  'sc_killthreads': [],
#  'sc_checkasyncscript': [],
#  'sc_findasyncmeasurements': ['sc_checkasyncscript'],
#  'endscan': ['scfd_checkrawsave',
#   'set_indep',
#   'scv_setlastscanvars',
#   'scv_getlastscanvars',
#   'savetohdf',
#   'saveexp',
#   'sc_checkbackup',
#   'sc_copynewfiles',
#   'sce_scanvarstojson'],
#  'savenamedwaves': ['openhdffile',
#   'addmetafiles',
#   'savesinglewavetohdf',
#   'closehdffile',
#   'sc_checkbackup',
#   'sc_copynewfiles'],
#  'sce_scanvarstojson': ['addjsonkeyval', 'prettyjsonfmt'],
#  'initscancontroller': ['gethostname',
#   'sc_checkbackup',
#   'sc_checksqldriver',
#   'getexppath',
#   'getfadcvalue',
#   'getk2400current',
#   'readsrsx',
#   'readsrsy',
#   'openmultiplefdacs',
#   'openls370connection',
#   'openips120connection',
#   'getfdstatus',
#   'getls370status',
#   'getipsstatus',
#   'scw_loadconfig',
#   'killvisa',
#   'scw_rebuildwindow'],
#  'scw_rebuildwindow': [],
#  'setupfakesquarewave': ['setfdacawgsquarewave'],
#  'scw_setupsquarewave': [],
#  'scw_setupawg': ['setupawg',
#   'scu_getchannelnumbers',
#   'ask_user',
#   'setfdacawgsquarewave'],
#  'scw_clearawinputs': [],
#  'scw_setuplockin': ['setfdacawgsquarewave', 'setupawg'],
#  'scw_openinstrbutton': ['sc_openinstrconnections'],
#  'scw_openguibutton': ['sc_openinstrguis'],
#  'scw_killgraphs': [],
#  'scw_updatewindow': ['scw_createconfig', 'scw_saveconfig'],
#  'scw_addrow': ['appendstring', 'appendvalue', 'scw_rebuildwindow'],
#  'scw_removerow': ['scw_rebuildwindow'],
#  'scw_checkboxclicked': [],
#  'scw_createconfig': ['addjsonkeyval',
#   'textwave2strarray',
#   'wave2boolarray',
#   'num2bool'],
#  'scw_saveconfig': ['scu_unixtime', 'writetofile'],
#  'scw_loadconfig': ['readtxtfile',
#   'getjsonvalue',
#   'loadstrarray2textwave',
#   'loadboolarray2wave',
#   'loadbool2var',
#   'loadnum2var',
#   'scw_rebuildwindow'],
#  'recordvalues': ['readvstime',
#   'sc_managethreads',
#   'sc_killthreads',
#   'scv_setlastscanvars',
#   'scs_checksweepstate',
#   'scg_updatefrequentgraphs'],
#  'prescanchecksfd': ['scc_checksamedevicefd',
#   'scc_checkrampratesfd',
#   'scc_checklimsfd'],
#  'prescanchecksbd': ['scc_checklimsbd'],
#  'prescancheckskeithley': [],
#  'checkawg': ['scc_checkawg'],
#  'checkstartsfinschannels': ['scu_assertseparatortype'],
#  'rampstartfd': ['scu_assertseparatortype', 'rampmultiplefdac'],
#  'scc_checkrampstartfd': ['rampstartfd',
#   'scu_assertseparatortype',
#   'getfdacoutput',
#   'sc_sleep'],
#  'scc_checkrampratesfd': ['scu_assertseparatortype',
#   'ask_user',
#   'recordvalues'],
#  'scc_checklimsfd': ['scc_checklimssinglefd'],
#  'scc_checklimssinglefd': ['scu_getchannelnumbers',
#   'ask_user',
#   'recordvalues'],
#  'scc_checksamedevicefd': ['scf_getchannelnumsonfd'],
#  'scc_getdeviceids': ['scf_getnumfds'],
#  'scc_checklimsbd': ['scu_assertseparatortype', 'bd_getboard', 'ask_user'],
#  'rampstartbd': ['ramptonextsetpoint'],
#  'scc_checkawg': ['checkawg',
#   'scu_assertseparatortype',
#   'scf_getnumrecordedadcs',
#   'fd_getawgwave',
#   'scanfastdac',
#   'ask_user'],
#  'ramptonextsetpoint': ['checkstartsfinschannels',
#   'rampmultiplefdac',
#   'rampmultiplebd'],
#  'scf_getdacinfo': ['scu_getchannelnumbers'],
#  'scf_checkinstridmatchesdevice': ['getresourceaddress'],
#  'scf_getfdnumber': ['scf_getnumfds',
#   'getresourceaddress',
#   'scf_getfdvisaaddress'],
#  'scf_getnumfds': [],
#  'scf_getfdvisaaddress': ['scf_getnumfds'],
#  'scf_getfdinfofromdevicenum': ['scf_getnumfds'],
#  'scf_getfdinfofromid': ['scf_getfdnumber', 'scf_getfdinfofromdevicenum'],
#  'scf_getrecordedfadcinfo': [],
#  'scf_getrecordedscancontrollerinfo': [],
#  'scf_getnumrecordedadcs': ['scf_getrecordedfadcinfo',
#   'scu_getdevicechannels'],
#  'scf_getmaxrecordedadcs': ['scf_getnumrecordedadcs'],
#  'scf_getchannelnumsonfd': ['scu_assertseparatortype',
#   'scf_getnumfds',
#   'scf_getfdinfofromdevicenum'],
#  'scf_getchannelnumsonfd2': ['scu_assertseparatortype',
#   'scf_getnumfds',
#   'scf_getfdinfofromdevicenum'],
#  'scf_getchannelstartnum': ['scf_getnumfds',
#   'scf_getfdnumber',
#   'scf_getfdinfofromid'],
#  'scfd_checkrawsave': ['scf_getrecordedfadcinfo'],
#  'scf_checkfdresponse': [],
#  'scf_addfdinfos': [],
#  'scfd_postfilternumpts': [],
#  'scfd_resamplewaves2': ['scfd_resamplewaves', 'scv_getlastscanvars'],
#  'scfd_resamplewaves': [],
#  'scfd_notch_filters': [],
#  'scfd_sqw_analysis': [],
#  'scfd_demodulate': [],
#  'scfd_spectrum_analyzer': [],
#  'scfd_recordvalues': ['recordvalues',
#   'rampstartfd',
#   'scc_checkrampstartfd',
#   'scfd_sendcommandandread',
#   'scfd_processanddistribute'],
#  'scfd_sendcommandandread': ['fd_start_sweep',
#   'scfd_recordbuffer',
#   'fd_stopfdacsweep',
#   'readinstr',
#   'sc_striptermination',
#   'scf_checkfdresponse',
#   'scfd_updatewindow',
#   'scu_getdevicechannels',
#   'removeseperator',
#   'rampmultiplefdac'],
#  'scfd_processanddistribute': ['sci_get1dwavenames',
#   'scf_getrecordedfadcinfo',
#   'scfd_notch_filters',
#   'scfd_sqw_analysis',
#   'scfd_demodulate',
#   'scfd_resamplewaves',
#   'scfd_spectrum_analyzer'],
#  'scfd_recordbuffer': ['roundnum',
#   'scfd_getreadchunksize',
#   'scfd_readchunk',
#   'scfd_distributedata1',
#   'scfd_checksweepstate',
#   'scg_updatefrequentgraphs'],
#  'scfd_expectedbytesinbuffer': [],
#  'scfd_getreadchunksize': [],
#  'scfd_raw2calcquickdistribute': ['sci_get1dwavenames',
#   'scf_getrecordedfadcinfo'],
#  'scfd_checksweepstate': ['scs_checksweepstate', 'fd_stopfdacsweep'],
#  'scfd_readchunk': ['readinstr', 'fd_stopfdacsweep'],
#  'scfd_distributedata1': ['scfd_distributedata2'],
#  'scfd_updatewindow': ['scu_assertseparatortype',
#   'scf_getchannelnumsonfd',
#   'scf_getfdvisaaddress',
#   'getresourceaddress',
#   'getfdacoutput',
#   'scfw_updatefdacvalstr',
#   'getfadcchannel'],
#  'scfd_distributedata2': ['scu_assertseparatortype',
#   'fd_char2num',
#   'scu_getdevicechannels'],
#  'scfw_resetfdacwindow': [],
#  'scfw_updateoldfdacstr': [],
#  'scfw_updatefdacvalstr': [],
#  'initfastdac': ['openfastdacconnection',
#   'scfw_fdaccheckforoldinit',
#   'scfw_setguiinteraction'],
#  'scfw_fdaccheckforoldinit': ['scfw_fdacaskuser', 'scfw_createcontrolwaves'],
#  'scfw_fdacaskuser': [],
#  'scfw_fdacaskuserupdate': ['scfw_fdacaskuser'],
#  'scfw_scfw_update_fadcspeed': ['scfw_update_fadc',
#   'sc_openinstrconnections',
#   'setfadcspeed'],
#  'scfw_update_all_fdac': ['sc_openinstrconnections',
#   'scf_getfdinfofromdevicenum',
#   'rampmultiplefdac',
#   'getfdacoutput',
#   'scfw_updatefdacvalstr'],
#  'scfw_update_fdac': ['scfw_update_all_fdac', 'sc_openinstrconnections'],
#  'scfw_update_fadc': ['sc_openinstrconnections',
#   'scf_getfdinfofromdevicenum',
#   'scf_getfdvisaaddress',
#   'getfadcchannel'],
#  'scfw_createcontrolwaves': [],
#  'scfw_setguiinteraction': ['setfadcspeed'],
#  'killvisa': [],
#  'getresourceaddress': [],
#  'visaerrormsg': [],
#  'openresourcemanager': ['visaerrormsg'],
#  'openvisainstr': ['closevisainstr',
#   'visaerrormsg',
#   'setvisaoptions',
#   'queryinstr'],
#  'closevisainstr': ['visaerrormsg'],
#  'closeallvisa': [],
#  'openhttpinstr': [],
#  'writeinstr': ['visaerrormsg'],
#  'readinstr': ['visasetreadterm',
#   'visasetreadtermenable',
#   'visasetserialendin',
#   'visaerrormsg'],
#  'queryinstr': ['writeinstr', 'readinstr'],
#  'queryinstrprogress': ['writeinstr', 'sc_progressbardelay', 'readinstr'],
#  'posthttp': ['getjsonvalue'],
#  'puthttp': ['getjsonvalue'],
#  'gethttp': [],
#  'sc_striptermination': [],
#  'sc_progressbardelay': [],
#  'gpibrenassert': [],
#  'listgpibinstr': ['openresourcemanager', 'visaerrormsg'],
#  'getaddressgpib': [],
#  'getserialinstrinfo': ['openresourcemanager', 'visaerrormsg'],
#  'listserialports': ['openresourcemanager'],
#  'setvisaoptions': ['visasetbaudrate',
#   'visasetstopbits',
#   'visasetdatabits',
#   'visasetparity',
#   'visasettimeout',
#   'visaerrormsg'],
#  'visasetreadterm': [],
#  'visasetreadtermenable': ['visasetreadterm'],
#  'visasettimeout': [],
#  'visasetbaudrate': [],
#  'visasetdatabits': [],
#  'visasetstopbits': [],
#  'visasetserialendout': [],
#  'visasetserialendin': [],
#  'visasetparity': [],
#  'openhdffile': ['endscan'],
#  'closehdffile': [],
#  'savewavestohdf': ['savesinglewavetohdf'],
#  'addmetafiles': ['scw_createconfig',
#   'sc_createsweeplogs',
#   'prettyjsonfmt',
#   'sce_scanvarstojson',
#   'sc_confirm_json',
#   'scw_saveconfig'],
#  'sc_createsweeplogs': ['addjsonkeyval',
#   'num2numstr',
#   'scf_getrecordedfadcinfo',
#   'sc_instrumentlogs'],
#  'sc_instrumentlogs': ['sc_openinstrconnections',
#   'sc_createsweeplogs',
#   'addjsonkeyval'],
#  'getrawsavenames': [],
#  'createwavescopyigor': [],
#  'savescanwaves': ['scfd_postfilternumpts'],
#  'savesinglewavetohdf': [],
#  'savetohdf': ['openhdffile',
#   'addmetafiles',
#   'savefastdacinfowaves',
#   'savescanwaves',
#   'sci_get1dwavenames',
#   'sci_get2dwavenames',
#   'scu_assertseparatortype',
#   'createwavescopyigor',
#   'savewavestohdf',
#   'closehdffile'],
#  'savefastdacinfowaves': ['fd_getglobalawg',
#   'fd_getawgwave',
#   'savesinglewavetohdf'],
#  'logsonlysave': ['addmetafiles', 'closehdffile'],
#  'saveexp': ['savefrompxp'],
#  'savefrompxp': [],
#  'sc_copysinglefile': ['getexppath', 'executemaccmd'],
#  'sc_copynewfiles': ['sc_copysinglefile', 'getexppath'],
#  'get_sweeplogs': [],
#  'gethostname': ['executemaccmd', 'executewincmd'],
#  'executewincmd': ['getexppath'],
#  'executemaccmd': [],
#  'getexppath': [],
#  'writetofile': [],
#  'readtxtfile': [],
#  'getjsonxid': ['getjsonxid_fromkey'],
#  'getjsonxid_fromkey': ['getjsonxid', 'getjsonvalue'],
#  'sc_confirm_json': [],
#  'getjsonvalue': ['getjsonkeyoffset', 'getjsonindices'],
#  'getjsonindices': [],
#  'getjsonkeyoffset': [],
#  'getstrarrayshape': [],
#  'loadstrarray2textwave': ['getstrarrayshape',
#   'escapequotes',
#   'unescapequotes'],
#  'getarrayshape': [],
#  'loadboolarray2wave': ['getarrayshape', 'bool2num'],
#  'loadnumarray2wave': ['getarrayshape'],
#  'loadbool2var': ['bool2num'],
#  'loadstr2string': ['removeliteralquotes', 'escapequotes', 'unescapequotes'],
#  'loadnum2var': [],
#  'bool2num': [],
#  'num2numstr': [],
#  'num2bool': [],
#  'wave2boolarray': ['num2bool'],
#  'wave2numarray': [],
#  'textwave2strarray': ['escapequotes'],
#  'get_values': [],
#  'textwavetolist': [],
#  'numwavetolist': [],
#  'addjsonkeyval': ['escapequotes'],
#  'getindent': [],
#  'prettyjsonfmt': ['getindent'],
#  'removeseperator': [],
#  'removetrailingwhitespace': [],
#  'removewhitespace': ['removetrailingwhitespace'],
#  'countquotes': [],
#  'escapequotes': [],
#  'unescapequotes': ['escapequotes'],
#  'removeliteralquotes': [],
#  'removestringlistduplicates': [],
#  'searchfullstring': [],
#  'requestsqldata': ['sc_opensqlconnection',
#   'sc_fetchsqldata',
#   'sc_closesqlconnection'],
#  'requestsqlvalue': ['sc_opensqlconnection',
#   'sc_fetchsqlsingle',
#   'sc_closesqlconnection'],
#  'sql_format_time': [],
#  'sc_opensqlconnection': ['sc_readsqlconnectionparameters'],
#  'sc_fetchsqlsingle': ['sc_closesqlconnection'],
#  'sc_fetchsqldata': ['sc_closesqlconnection', 'sc_mapsqltypetowavetype'],
#  'sc_closesqlconnection': [],
#  'sc_readsqlconnectionparameters': ['readtxtfile', 'getjsonvalue'],
#  'sc_mapsqltypetowavetype': [],
#  'sc_checksqldriver': [],
#  'timestamp2secs': [],
#  'sc_sqldatabasetime': ['requestsqlvalue'],
#  'sc_sqltimestamp': ['sc_sqldatabasetime', 'timestamp2secs'],
#  'sc_sqlinformation_schema': ['sc_readsqlconnectionparameters'],
#  'sc_fetchsqldatatest': ['sc_fetchsqldata', 'sc_readsqlconnectionparameters'],
#  'timesqlstatements': ['requestsqldata', 'requestsqlvalue'],
#  'readvstime': ['initscanvars',
#   'initscanvarsbd',
#   'initializescan',
#   'asleep',
#   'recordvalues',
#   'endscan'],
#  'scanbabydac': ['sc_openinstrconnections',
#   'initscanvars',
#   'initscanvarsbd',
#   'prescanchecksbd',
#   'rampstartbd',
#   'sc_sleep',
#   'initializescan',
#   'ramptonextsetpoint',
#   'recordvalues',
#   'endscan'],
#  'scanbabydacuntil': ['scanbabydac',
#   'sc_openinstrconnections',
#   'initscanvars',
#   'initscanvarsbd',
#   'prescanchecksbd',
#   'rampstartbd',
#   'sc_sleep',
#   'initializescan',
#   'ramptonextsetpoint',
#   'recordvalues',
#   'endscan'],
#  'scanbabydac2d': ['scanbabydac',
#   'sc_openinstrconnections',
#   'initscanvars',
#   'initscanvarsbd',
#   'prescanchecksbd',
#   'rampstartbd',
#   'sc_sleep',
#   'initializescan',
#   'ramptonextsetpoint',
#   'recordvalues',
#   'endscan'],
#  'scanbabydac_srsamplitude': ['scanbabydac',
#   'sc_openinstrconnections',
#   'initscanvars',
#   'initscanvarsbd',
#   'prescanchecksbd',
#   'rampstartbd',
#   'sc_sleep',
#   'initializescan',
#   'ramptonextsetpoint',
#   'setsrsamplitude',
#   'recordvalues',
#   'endscan'],
#  'readvstimefastdac': ['readvstime',
#   'scf_getrecordedfadcinfo',
#   'initscanvars',
#   'initscanvarsfd',
#   'initializescan',
#   'recordvalues',
#   'scfd_recordvalues',
#   'endscan'],
#  'scanfastdac': ['sc_openinstrconnections',
#   'initscanvars',
#   'initscanvarsfd',
#   'initscanvarsfd2',
#   'prescanchecksfd',
#   'fd_getglobalawg',
#   'checkawg',
#   'setawg',
#   'set_master_slave',
#   'rampstartfd',
#   'sc_sleep',
#   'initializescan',
#   'set_awg_state',
#   'ramp_interlaced_channels',
#   'recordvalues',
#   'scfd_recordvalues',
#   'endscan',
#   'set_indep'],
#  'scanfastdacslow': ['scanfastdac',
#   'sc_openinstrconnections',
#   'initscanvars',
#   'initscanvarsfd',
#   'initscanvarsfd2',
#   'scc_checklimsfd',
#   'rampstartfd',
#   'sc_sleep',
#   'initializescan',
#   'ramptonextsetpoint',
#   'recordvalues',
#   'stoppid',
#   'clearfdacbuffer',
#   'endscan'],
#  'scanfastdacslow2d': ['scanfastdac',
#   'scanfastdacslow',
#   'sc_openinstrconnections',
#   'initscanvars',
#   'initscanvarsfd',
#   'initscanvarsfd2',
#   'scc_checklimsfd',
#   'rampstartfd',
#   'sc_sleep',
#   'initializescan',
#   'ramptonextsetpoint',
#   'recordvalues',
#   'endscan'],
#  'scanfastdac2d': ['scanfastdac',
#   'sc_openinstrconnections',
#   'initscanvars',
#   'initscanvarsfd',
#   'initscanvarsfd2',
#   'scu_getchannelnumbers',
#   'scu_getdaclabel',
#   'scv_setsetpoints',
#   'prescanchecksbd',
#   'prescanchecksfd',
#   'set_master_slave',
#   'fd_getglobalawg',
#   'checkawg',
#   'setawg',
#   'rampstartfd',
#   'rampstartbd',
#   'sc_sleep',
#   'initializescan',
#   'ramp_interlaced_channels',
#   'set_awg_state',
#   'ramptonextsetpoint',
#   'recordvalues',
#   'scfd_recordvalues',
#   'endscan'],
#  'set_awg_state': [],
#  'ramp_interlaced_channels': ['scu_getchannelnumbers',
#   'scf_getchannelnumsonfd',
#   'openfastdacconnection',
#   'rampmultiplefdac'],
#  'scank2400': ['sc_openinstrconnections',
#   'initscanvars',
#   'rampk2400voltage',
#   'sc_sleep',
#   'initializescan',
#   'setk2400voltage',
#   'recordvalues',
#   'endscan'],
#  'scank24002d': ['scank2400',
#   'sc_openinstrconnections',
#   'initscanvars',
#   'rampk2400voltage',
#   'sc_sleep',
#   'initializescan',
#   'setk2400voltage',
#   'recordvalues',
#   'endscan'],
#  'scanbabydack24002d': ['scanbabydac',
#   'sc_openinstrconnections',
#   'initscanvars',
#   'initscanvarsbd',
#   'prescanchecksbd',
#   'rampstartbd',
#   'rampk2400voltage',
#   'sc_sleep',
#   'initializescan',
#   'ramptonextsetpoint',
#   'recordvalues',
#   'endscan'],
#  'scanbabydacmultiplek24002d': ['scanbabydac',
#   'sc_openinstrconnections',
#   'initscanvars',
#   'scv_setsetpoints',
#   'prescanchecksbd',
#   'ramptonextsetpoint',
#   'rampmultiplek2400s',
#   'sc_sleep',
#   'initializescan',
#   'recordvalues',
#   'endscan'],
#  'scanfastdack24002d': ['scanfastdac',
#   'sc_openinstrconnections',
#   'initscanvars',
#   'initscanvarsfd',
#   'initscanvarsfd2',
#   'prescanchecksfd',
#   'set_master_slave',
#   'rampstartfd',
#   'rampk2400voltage',
#   'sc_sleep',
#   'initializescan',
#   'recordvalues',
#   'scfd_recordvalues',
#   'endscan'],
#  'scanmultiplek2400': ['sc_openinstrconnections',
#   'initscanvars',
#   'scv_setsetpoints',
#   'rampmultiplek2400s',
#   'sc_sleep',
#   'initializescan',
#   'recordvalues',
#   'endscan'],
#  'scanmultiplek2400ls625magnet2d': ['scanmultiplek2400',
#   'sc_openinstrconnections',
#   'initscanvars',
#   'rampmultiplek2400s',
#   'setls625field',
#   'setls625fieldwait',
#   'sc_sleep',
#   'initializescan',
#   'recordvalues',
#   'endscan'],
#  'scanls625magnet': ['sc_openinstrconnections',
#   'initscanvars',
#   'getls625rate',
#   'setls625field',
#   'setls625fieldwait',
#   'sc_sleep',
#   'initializescan',
#   'recordvalues',
#   'endscan'],
#  'scanbabydacls625magnet2d': ['scanbabydac',
#   'sc_openinstrconnections',
#   'initscanvars',
#   'initscanvarsbd',
#   'prescanchecksbd',
#   'rampstartbd',
#   'setls625field',
#   'setls625fieldwait',
#   'sc_sleep',
#   'initializescan',
#   'ramptonextsetpoint',
#   'recordvalues',
#   'endscan'],
#  'scanfastdacls625magnet2d': ['scanfastdac',
#   'sc_openinstrconnections',
#   'initscanvars',
#   'initscanvarsfd',
#   'initscanvarsfd2',
#   'prescanchecksfd',
#   'set_master_slave',
#   'rampstartfd',
#   'setls625field',
#   'setls625fieldwait',
#   'sc_sleep',
#   'initializescan',
#   'recordvalues',
#   'scfd_recordvalues',
#   'endscan'],
#  'scanfastdacslowls625magnet2d': ['scanfastdac',
#   'scanfastdacslow',
#   'sc_openinstrconnections',
#   'initscanvars',
#   'initscanvarsfd',
#   'initscanvarsfd2',
#   'scc_checklimsfd',
#   'rampstartfd',
#   'setls625rate',
#   'setls625field',
#   'setls625fieldwait',
#   'asleep',
#   'initializescan',
#   'sc_sleep',
#   'ramptonextsetpoint',
#   'recordvalues',
#   'endscan'],
#  'scanfastdacips120magnet2d': ['scanfastdac',
#   'sc_openinstrconnections',
#   'initscanvars',
#   'initscanvarsfd',
#   'initscanvarsfd2',
#   'prescanchecksfd',
#   'set_master_slave',
#   'rampstartfd',
#   'setips120field',
#   'setips120fieldwait',
#   'sc_sleep',
#   'initializescan',
#   'recordvalues',
#   'scfd_recordvalues',
#   'endscan'],
#  'scanfastdacslowips120magnet2d': ['scanfastdac',
#   'scanfastdacslow',
#   'sc_openinstrconnections',
#   'initscanvars',
#   'initscanvarsfd',
#   'initscanvarsfd2',
#   'scc_checklimsfd',
#   'rampstartfd',
#   'setips120field',
#   'setips120fieldwait',
#   'asleep',
#   'initializescan',
#   'sc_sleep',
#   'ramptonextsetpoint',
#   'recordvalues',
#   'endscan'],
#  'scank2400ls625magnet2d': ['scank2400',
#   'sc_openinstrconnections',
#   'initscanvars',
#   'rampk2400voltage',
#   'setls625rate',
#   'setls625field',
#   'setls625fieldwait',
#   'sc_sleep',
#   'initializescan',
#   'recordvalues',
#   'endscan'],
#  'scansrsfrequency': ['sc_openinstrconnections',
#   'initscanvars',
#   'setsrsfrequency',
#   'sc_sleep',
#   'initializescan',
#   'recordvalues',
#   'endscan'],
#  'scanmultivartemplate': [],
#  'steptempscansomething': ['setls370exclusivereader',
#   'setls370temp',
#   'sc_sleep',
#   'waittilltempstable',
#   'setls370heateroff',
#   'resetls370exclusivereader'],
#  'steptempscanfunc': ['setls625field',
#   'setls625fieldwait',
#   'asleep',
#   'getls370temp',
#   'setls370exclusivereader',
#   'setls370temp',
#   'waittilltempstable',
#   'setls370heateroff',
#   'resetls370exclusivereader'],
#  'opensrsconnection': ['visaerrormsg', 'openvisainstr'],
#  'readsrsx': ['queryinstr'],
#  'readsrsy': ['queryinstr'],
#  'readsrsr': ['queryinstr'],
#  'readsrst': ['queryinstr'],
#  'getsrsharmonic': ['queryinstr'],
#  'getsrstimeconst': ['queryinstr'],
#  'getsrsphase': ['queryinstr'],
#  'getsrsamplitude': ['queryinstr'],
#  'getsrsfrequency': ['queryinstr'],
#  'getsrsreadout': ['queryinstr'],
#  'getsrssensitivity': ['queryinstr'],
#  'readsrsjunk': [],
#  'setsrsharmonic': ['writeinstr'],
#  'setsrstimeconst': ['writeinstr'],
#  'setsrsphase': ['writeinstr'],
#  'autosrsphase': ['writeinstr'],
#  'setsrsreadout': ['writeinstr'],
#  'setsrsamplitude': ['writeinstr'],
#  'setsrsfrequency': ['writeinstr'],
#  'setsrssensitivity': ['writeinstr'],
#  'setsrssensup': ['getsrssensitivity', 'writeinstr'],
#  'setsrssensdown': ['getsrssensitivity', 'writeinstr'],
#  'getsrsstatus': ['getaddressgpib',
#   'addjsonkeyval',
#   'num2numstr',
#   'getsrsamplitude',
#   'getsrstimeconst',
#   'getsrsfrequency',
#   'getsrsphase',
#   'getsrssensitivity',
#   'getsrsharmonic',
#   'getsrsreadout']}

# %%
function_gets_called = "ScanFastDAC" # CHANGE THIS STRING, I TAKE CARE OF UPPER AND LOWER CASE
functions_that_call_x = []


for key, val in function_functions.items():
    if function_gets_called.lower() in val:
        functions_that_call_x.append(key)


print(functions_that_call_x)
# Out:
# ['scc_checkawg', 'scanfastdacslow', 'scanfastdacslow2d', 'scanfastdac2d', 'scanfastdack24002d', 'scanfastdacls625magnet2d', 'scanfastdacslowls625magnet2d', 'scanfastdacips120magnet2d', 'scanfastdacslowips120magnet2d']
